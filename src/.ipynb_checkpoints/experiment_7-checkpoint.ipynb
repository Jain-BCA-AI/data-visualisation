# %% [markdown]
# ## HeatMap and Wordcloud

# %%
import seaborn as sns
import numpy as np

# %%
#Loading the dataset 
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Finding the correlation
tips.corr()
# Out:
# /var/folders/42/588fpm_j2l9gcqjmrf8fpzqw0000gn/T/ipykernel_42856/2690112336.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#Generating the heatmap for correlation for tips
sns.heatmap(tips.corr())
# Out:
# /var/folders/42/588fpm_j2l9gcqjmrf8fpzqw0000gn/T/ipykernel_42856/1656838032.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr())
# <AxesSubplot: >

# %%
#Adding cmap parameter to heatmap
sns.heatmap(tips.corr(),cmap='coolwarm')
# Out:
# /var/folders/42/588fpm_j2l9gcqjmrf8fpzqw0000gn/T/ipykernel_42856/2349541276.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr(),cmap='coolwarm')
# <AxesSubplot: >

# %%
#Adding annot parameter to heatmap
sns.heatmap(tips.corr(),cmap='Greens',annot=True)
# Out:
# /var/folders/42/588fpm_j2l9gcqjmrf8fpzqw0000gn/T/ipykernel_42856/3539293846.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr(),cmap='Greens',annot=True)
# <AxesSubplot: >

# %%
#Adding linecolor,linewidth parameters to heatmap
sns.heatmap(tips.corr(),cmap='PiYG',annot=True,linecolor='black',linewidth=3)
# Out:
# /var/folders/42/588fpm_j2l9gcqjmrf8fpzqw0000gn/T/ipykernel_42856/532672934.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr(),cmap='PiYG',annot=True,linecolor='black',linewidth=3)
# <AxesSubplot: >

# %% [markdown]
# ## Wordcloud

# %%
#Installing packages
conda install wordcloud wikipedia pillow
# Out:
#   Input In [13]
#     conda install wordcloud wikipedia pillow
#           ^
# SyntaxError: invalid syntax

# %%
#Importing packages
from wordcloud import WordCloud,STOPWORDS
import wikipedia as wiki
from PIL import Image

# %%
#Setting stopwords 
stop_w=set(STOPWORDS)

# %%
#Getting information from wikipedia
info=wiki.summary('python programming')
info
# Out:
# 'Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation.Python is dynamically-typed and garbage-collected. It supports multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming. It is often described as a "batteries included" language due to its comprehensive standard library.Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language and first released it in 1991 as Python 0.9.0. Python 2.0 was released in 2000 and introduced new features such as list comprehensions, cycle-detecting garbage collection, reference counting, and Unicode support. Python 3.0, released in 2008, was a major revision that is not completely backward-compatible with earlier versions. Python 2 was discontinued with version 2.7.18 in 2020.Python consistently ranks as one of the most popular programming languages.'

# %%
#Generating the worldcloud
wcl=WordCloud(stopwords=stop_w).generate(info)

# %%
#Displaying the wordcloud
img=wcl.to_image()
img
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x2980213D250>

# %%
#Getting information from wikipedia
out=wiki.summary('Jain University',sentences=5)
out
# Out:
# 'Jain University, officially JAIN (Deemed-to-be University), is a private deemed-to-be-university located in Bangalore, India. Originating from Sri Bhagawan Mahaveer Jain College, it was conferred the deemed-to-be-university status in 2009.On August 2019 Jain University Opened a new campus in Kochi\n\n\n== History ==\nJain University originates from Sri Bhagawan Mahaveer Jain College (SBMJC), established by the founder and chairman of JGI GROUP, Dr.Chenraj Roychand in 1990. It was conferred deemed to be university status in 2009. People also search for Jain University Kochi News to get the latest updates.\nThe Jain (Deemed to be University) has to put its administrative officers contact details.'

# %%
#f=open('C:\\Users\\CHANDRU\\OneDrive\\Desktop\\bird.jpg','r')
#f
# Out:
# <_io.TextIOWrapper name='C:\\Users\\CHANDRU\\OneDrive\\Desktop\\bird.jpg' mode='r' encoding='cp1252'>

# %%
#Masking the image
mask_img=np.array(Image.open("C:\\Users\\CHANDRU\\OneDrive\\Desktop\\bird.jpg"))

# %%
#generating the wordcloud in shape of masked image
wc=WordCloud(mask=mask_img,
             prefer_horizontal=0.5,
             background_color="rgba(255, 255, 255, 0)", 
             mode="RGBA",
             stopwords=stop_w).generate(out)
wc

# %%
img=wc.to_image()

# %%
display(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=391x252 at 0x29809976EE0>
